# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %%
market_data = pd.read_csv("C:\\Users\\MANJU SWAROOP V\\OneDrive\\Desktop\\PE-ASSIGNMENT\\mod3_q1\\market_data.csv", header=None)
market_data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
records = []
for i in range(1, 7501):
    records.append([str(store_data.values[i, j]) for j in range(0, 20)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0030, min_confidence=0.40, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 62 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'avocado', 'milk', 'spaghetti'})
# frozenset({'ground beef', 'cereals', 'spaghetti'})
# frozenset({'ground beef', 'chicken', 'milk'})
# frozenset({'milk', 'chicken', 'olive oil'})
# frozenset({'chocolate', 'ground beef', 'herb & pepper'})
# frozenset({'ground beef', 'cooking oil', 'spaghetti'})
# frozenset({'eggs', 'red wine', 'spaghetti'})
# frozenset({'ground beef', 'herb & pepper', 'french fries'})
# frozenset({'milk', 'frozen vegetables', 'olive oil'})
# frozenset({'soup', 'milk', 'frozen vegetables'})
# frozenset({'soup', 'ground beef', 'milk'})
# frozenset({'ground beef', 'shrimp', 'spaghetti'})
# frozenset({'ground beef', 'tomato sauce', 'spaghetti'})
# frozenset({'milk', 'shrimp', 'olive oil'})
# frozenset({'soup', 'milk', 'olive oil'})
# frozenset({'soup', 'milk', 'tomatoes'})
# frozenset({'whole wheat pasta', 'milk', 'spaghetti'})
# frozenset({'whole wheat pasta', 'olive oil', 'mineral water'})
# frozenset({'tomatoes', 'spaghetti', 'olive oil'})
# ...

# %%
for item in association_results:
    
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    print("Support: " + str(item[1]))

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: avocado -> milk
# Support: 0.0033333333333333335
# Confidence: 0.4166666666666667
# Lift: 3.2150205761316877
# ...
# Rule: ground beef -> cereals
# Support: 0.0030666666666666668
# Confidence: 0.676470588235294
# Lift: 3.884785154490586
# ...
# Rule: ground beef -> chicken
# Support: 0.0038666666666666667
# Confidence: 0.4084507042253521
# Lift: 3.151625804207964
# ...
# Rule: milk -> chicken
# Support: 0.0036
# Confidence: 0.5
# Lift: 3.858024691358025
# ...
# Rule: chocolate -> ground beef
# Support: 0.004
# Confidence: 0.4411764705882353
# Lift: 4.489584164737808
# ...
# Rule: ground beef -> cooking oil
# Support: 0.0048
# Confidence: 0.5714285714285714
# Lift: 3.281557646029315
# ...
# Rule: eggs -> red wine
# Support: 0.0037333333333333333
# Confidence: 0.5283018867924528
# Lift: 3.0338929180271026
# ...
# Rule: ground beef -> herb & pepper
# Support: 0.0032
# Confidence: 0.46153846153846156
# Lift: 4.6967957415718615
# ...
# Rule: milk -> frozen vegetables
# Support: 0.0048
# Confidence: 0.4235294117647058
# ...
